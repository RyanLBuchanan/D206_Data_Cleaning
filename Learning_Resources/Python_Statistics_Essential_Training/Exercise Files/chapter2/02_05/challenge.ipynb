# %%
import numpy as np
import pandas as pd

import matplotlib 
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
df = pd.read_csv('tb.csv').head()

# %%
df.head()
# Out:
#   country  year  m04  m514  m014  m1524  m2534  m3544  m4554  m5564  ...  f04  \
# 0      AD  1989  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 1      AD  1990  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 2      AD  1991  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 3      AD  1992  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 4      AD  1993  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
#
#    f514  f014  f1524  f2534  f3544  f4554  f5564  f65  fu
# 0   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 1   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 2   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 3   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 4   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'm04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
#        'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
#        'f3544', 'f4554', 'f5564', 'f65', 'fu'],
#       dtype='object')

# %%
data = pd.read_csv('tb.csv')

# %%
data
# Out:
#      country  year  m04   m514   m014  m1524   m2534   m3544   m4554  m5564  \
# 0         AD  1989  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 1         AD  1990  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 2         AD  1991  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 3         AD  1992  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 4         AD  1993  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# ...      ...   ...  ...    ...    ...    ...     ...     ...     ...    ...
# 5764      ZW  2004  NaN    NaN  187.0  833.0  2908.0  2298.0  1056.0  366.0
# 5765      ZW  2005  NaN    NaN  210.0  837.0  2264.0  1855.0   762.0  295.0
# 5766      ZW  2006  NaN    NaN  215.0  736.0  2391.0  1939.0   896.0  348.0
# 5767      ZW  2007  6.0  132.0  138.0  500.0  3693.0     0.0   716.0  292.0
# 5768      ZW  2008  NaN    NaN  127.0  614.0     0.0  3316.0   704.0  263.0
#
# ...

# %%
data.dtypes
# Out:
# country     object
# year         int64
# m04        float64
# m514       float64
# m014       float64
# m1524      float64
# m2534      float64
# m3544      float64
# m4554      float64
# m5564      float64
# m65        float64
# mu         float64
# f04        float64
# f514       float64
# f014       float64
# f1524      float64
# f2534      float64
# f3544      float64
# f4554      float64
# f5564      float64
# f65        float64
# fu         float64
# dtype: object

# %%
tb_cases = data['country'].unique()

# %%
print(tb_cases)
# Out:
# ['AD' 'AE' 'AF' 'AG' 'AI' 'AL' 'AM' 'AN' 'AO' 'AR' 'AS' 'AT' 'AU' 'AZ'
#  'BA' 'BB' 'BD' 'BE' 'BF' 'BG' 'BH' 'BI' 'BJ' 'BM' 'BN' 'BO' 'BR' 'BS'
#  'BT' 'BW' 'BY' 'BZ' 'CA' 'CD' 'CF' 'CG' 'CH' 'CI' 'CK' 'CL' 'CM' 'CN'
#  'CO' 'CR' 'CU' 'CV' 'CY' 'CZ' 'DE' 'DJ' 'DK' 'DM' 'DO' 'DZ' 'EC' 'EE'
#  'EG' 'ER' 'ES' 'ET' 'FI' 'FJ' 'FM' 'FR' 'GA' 'GB' 'GD' 'GE' 'GH' 'GM'
#  'GN' 'GQ' 'GR' 'GT' 'GU' 'GW' 'GY' 'HK' 'HN' 'HR' 'HT' 'HU' 'ID' 'IE'
#  'IL' 'IN' 'IQ' 'IR' 'IS' 'IT' 'JM' 'JO' 'JP' 'KE' 'KG' 'KH' 'KI' 'KM'
#  'KN' 'KP' 'KR' 'KW' 'KY' 'KZ' 'LA' 'LB' 'LC' 'LK' 'LR' 'LS' 'LT' 'LU'
#  'LV' 'LY' 'MA' 'MC' 'MD' 'ME' 'MG' 'MH' 'MK' 'ML' 'MM' 'MN' 'MO' 'MP'
#  'MR' 'MS' 'MT' 'MU' 'MV' 'MW' 'MX' 'MY' 'MZ' nan 'NC' 'NE' 'NG' 'NI' 'NL'
#  'NO' 'NP' 'NR' 'NU' 'NZ' 'OM' 'PA' 'PE' 'PF' 'PG' 'PH' 'PK' 'PL' 'PR'
#  'PS' 'PT' 'PW' 'PY' 'QA' 'RO' 'RS' 'RU' 'RW' 'SA' 'SB' 'SC' 'SD' 'SE'
#  'SG' 'SI' 'SK' 'SL' 'SM' 'SN' 'SO' 'SR' 'ST' 'SV' 'SY' 'SZ' 'TC' 'TD'
# ...

# %%
df = pd.read_csv('tb.csv')

# %%
tb_cases = df['country'].value_counts()
print(tb_cases)
# Out:
# MD    29
# SG    29
# SK    29
# JO    29
# MA    29
#       ..
# AN    13
# VG    10
# TL     8
# RS     4
# ME     4
# Name: country, Length: 212, dtype: int64

# %%
tb_cases = df.loc[df.duplicated()]
tb_cases
# Out:
# Empty DataFrame
# Columns: [country, year, m04, m514, m014, m1524, m2534, m3544, m4554, m5564, m65, mu, f04, f514, f014, f1524, f2534, f3544, f4554, f5564, f65, fu]
# Index: []
#
# [0 rows x 22 columns]

# %%
tb = tb_cases

# %%
tb
# Out:
# Empty DataFrame
# Columns: [country, year, m04, m514, m014, m1524, m2534, m3544, m4554, m5564, m65, mu, f04, f514, f014, f1524, f2534, f3544, f4554, f5564, f65, fu]
# Index: []
#
# [0 rows x 22 columns]

# %%
tb = pd.read_csv('tb.csv')

# %%
tb
# Out:
#      country  year  m04   m514   m014  m1524   m2534   m3544   m4554  m5564  \
# 0         AD  1989  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 1         AD  1990  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 2         AD  1991  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 3         AD  1992  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 4         AD  1993  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# ...      ...   ...  ...    ...    ...    ...     ...     ...     ...    ...
# 5764      ZW  2004  NaN    NaN  187.0  833.0  2908.0  2298.0  1056.0  366.0
# 5765      ZW  2005  NaN    NaN  210.0  837.0  2264.0  1855.0   762.0  295.0
# 5766      ZW  2006  NaN    NaN  215.0  736.0  2391.0  1939.0   896.0  348.0
# 5767      ZW  2007  6.0  132.0  138.0  500.0  3693.0     0.0   716.0  292.0
# 5768      ZW  2008  NaN    NaN  127.0  614.0     0.0  3316.0   704.0  263.0
#
# ...

# %%
df
# Out:
#      country  year  m04   m514   m014  m1524   m2534   m3544   m4554  m5564  \
# 0         AD  1989  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 1         AD  1990  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 2         AD  1991  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 3         AD  1992  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 4         AD  1993  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# ...      ...   ...  ...    ...    ...    ...     ...     ...     ...    ...
# 5764      ZW  2004  NaN    NaN  187.0  833.0  2908.0  2298.0  1056.0  366.0
# 5765      ZW  2005  NaN    NaN  210.0  837.0  2264.0  1855.0   762.0  295.0
# 5766      ZW  2006  NaN    NaN  215.0  736.0  2391.0  1939.0   896.0  348.0
# 5767      ZW  2007  6.0  132.0  138.0  500.0  3693.0     0.0   716.0  292.0
# 5768      ZW  2008  NaN    NaN  127.0  614.0     0.0  3316.0   704.0  263.0
#
# ...

# %%
data = df.isnull().sum()
print(data)
# Out:
# country      23
# year          0
# m04        5377
# m514       5368
# m014       3388
# m1524      3362
# m2534      3361
# m3544      3354
# m4554      3348
# m5564      3355
# m65        3361
# mu         5496
# f04        5376
# f514       5365
# f014       3391
# f1524      3375
# f2534      3369
# f3544      3371
# f4554      3368
# f5564      3375
# f65        3373
# fu         5497
# dtype: int64

# %%
tb
# Out:
#      country  year  m04   m514   m014  m1524   m2534   m3544   m4554  m5564  \
# 0         AD  1989  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 1         AD  1990  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 2         AD  1991  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 3         AD  1992  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# 4         AD  1993  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN
# ...      ...   ...  ...    ...    ...    ...     ...     ...     ...    ...
# 5764      ZW  2004  NaN    NaN  187.0  833.0  2908.0  2298.0  1056.0  366.0
# 5765      ZW  2005  NaN    NaN  210.0  837.0  2264.0  1855.0   762.0  295.0
# 5766      ZW  2006  NaN    NaN  215.0  736.0  2391.0  1939.0   896.0  348.0
# 5767      ZW  2007  6.0  132.0  138.0  500.0  3693.0     0.0   716.0  292.0
# 5768      ZW  2008  NaN    NaN  127.0  614.0     0.0  3316.0   704.0  263.0
#
# ...

# %%
melted = tb.melt(['country', 'year'],['m04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
       'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
       'f3544', 'f4554', 'f5564', 'f65', 'fu'], 'sexage', 'cases')

# %%
 melted.head()
# Out:
#   country  year sexage  cases
# 0      AD  1989    m04    NaN
# 1      AD  1990    m04    NaN
# 2      AD  1991    m04    NaN
# 3      AD  1992    m04    NaN
# 4      AD  1993    m04    NaN

# %%
melted['sex'] = melted['sexage'].str.slice(0,1)
melted['age'] = melted['sexage'].str.slice(1)

# %%
melted.head()
# Out:
#   country  year sexage  cases sex age
# 0      AD  1989    m04    NaN   m  04
# 1      AD  1990    m04    NaN   m  04
# 2      AD  1991    m04    NaN   m  04
# 3      AD  1992    m04    NaN   m  04
# 4      AD  1993    m04    NaN   m  04

# %%
melted
# Out:
#        country  year sexage  cases sex age
# 0           AD  1989    m04    NaN   m  04
# 1           AD  1990    m04    NaN   m  04
# 2           AD  1991    m04    NaN   m  04
# 3           AD  1992    m04    NaN   m  04
# 4           AD  1993    m04    NaN   m  04
# ...        ...   ...    ...    ...  ..  ..
# 115375      ZW  2004     fu    NaN   f   u
# 115376      ZW  2005     fu    NaN   f   u
# 115377      ZW  2006     fu    NaN   f   u
# 115378      ZW  2007     fu    NaN   f   u
# 115379      ZW  2008     fu    0.0   f   u
#
# [115380 rows x 6 columns]

# %%
tb.columns
# Out:
# Index(['country', 'year', 'm04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
#        'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
#        'f3544', 'f4554', 'f5564', 'f65', 'fu'],
#       dtype='object')

# %%
melted['age'] = melted['age'].map({'04': '0-4', '514': '5-14', '014': '0-14', '15-24': '15-24',
                                  '2534': '25-34', '3544': '35-44', '4554': '45-54', '5564': '55-64',
                                  '65': '65+'})

# %%
melted['age']
# Out:
# 0         0-4
# 1         0-4
# 2         0-4
# 3         0-4
# 4         0-4
#          ...
# 115375    NaN
# 115376    NaN
# 115377    NaN
# 115378    NaN
# 115379    NaN
# Name: age, Length: 115380, dtype: object
